# %%
from dataset.train_status_creation import creating_train_status_dataset
creating_train_status_dataset()
# Out:
# Simulating for Holiday time: 2024-01-01 06:00:00
# Processing Line1
# Processing Line2
# Processing Line3
# Processing Line4
# Simulating for Holiday time: 2024-01-01 06:06:00
# Processing Line1
# Processing Line2
# Processing Line3
# Processing Line4
# Simulating for Holiday time: 2024-01-01 06:12:00
# Processing Line1
# Processing Line2
# Processing Line3
# Processing Line4
# Simulating for Holiday time: 2024-01-01 06:18:00
# Processing Line1
# Processing Line2
# Processing Line3
# Processing Line4
# Simulating for Holiday time: 2024-01-01 06:24:00
# Processing Line1
# Processing Line2
# Processing Line3
# Processing Line4
# Simulating for Holiday time: 2024-01-01 06:30:00
# Processing Line1
# Processing Line2
# Processing Line3
# Processing Line4
# Simulating for Holiday time: 2024-01-01 06:36:00
# Processing Line1
# Processing Line2
# Processing Line3
# Processing Line4
# Simulating for Holiday time: 2024-01-01 06:42:00
# Processing Line1
# Processing Line2
# Processing Line3
# ...

# %%
from dataset.metro import Metro
cursed_metro = Metro()
cursed_metro.metro_simulation_one_day()
# Out:
# Simulating for Weekday time: 2024-01-01 06:00:00
# Processing Line1
# passenger flow started for Tajrish
# Simulated passengers flow at Tajrish
# passenger flow started for Shariati
# Simulated passengers flow at Shariati
# passenger flow started for Beheshti
# Simulated passengers flow at Beheshti
# passenger flow started for Dowlat
# Simulated passengers flow at Dowlat
# passenger flow started for Mohamadieh
# Simulated passengers flow at Mohamadieh
# passenger flow started for Kahrizak
# Simulated passengers flow at Kahrizak
# Processing Line2
# passenger flow started for Sanat
# Simulated passengers flow at Sanat
# passenger flow started for Valiasr
# Simulated passengers flow at Valiasr
# passenger flow started for Theather
# Simulated passengers flow at Theather
# passenger flow started for Mohamadieh
# Simulated passengers flow at Mohamadieh
# passenger flow started for Heravi
# Simulated passengers flow at Heravi
# passenger flow started for Basij
# ...
