# %%
from dataset.metro import Metro
cursed_metro = Metro()
cursed_metro.create_metro_graph()
cursed_metro.metro_simulation_one_day()
# Out:
# Simulating for time: 2024-01-01 06:00:00
# Processing Line1
# passenger flow started for Tajrish
# Simulated passengers flow at Tajrish
# passenger flow started for Shariati
# Simulated passengers flow at Shariati
# passenger flow started for Beheshti
# Simulated passengers flow at Beheshti
# passenger flow started for Dowlat
# Simulated passengers flow at Dowlat
# passenger flow started for Mohamadieh
# Simulated passengers flow at Mohamadieh
# passenger flow started for Kahrizak
# Simulated passengers flow at Kahrizak
# Processing Line2
# passenger flow started for Sanat
# Simulated passengers flow at Sanat
# passenger flow started for Valiasr
# Simulated passengers flow at Valiasr
# passenger flow started for Theather
# Simulated passengers flow at Theather
# passenger flow started for Mohamadieh
# Simulated passengers flow at Mohamadieh
# passenger flow started for Heravi
# Simulated passengers flow at Heravi
# passenger flow started for Basij
# ...
